# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim

# numpy and matplotlib
import numpy as np
import matplotlib.pyplot as plt

import os
from PIL import Image
import sys

# %%
# initialize for  each parameters
DATASET = 'CIFAR10'
BATCH_SIZE = 100
NUM_WORKERS = 2

WEIGHT_DECAY = 0.007
LEARNING_RATE = 0.01
MOMENTUM = 0.9

SCHEDULER_STEPS = 100
SCHEDULER_GAMMA = 0.1

SEED = 1

EPOCH = 150

KD_LAMBDA = 2.0

TRIPLET_MARGINE = 5.0

# %%
# !pwd
# Out:
# /ssd_scratch/cvit/sashank.sridhar

# %%
# fixing the seed
torch.cuda.manual_seed_all(SEED)
torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
# check if gpu is available
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("gpu mode")
else:
    device = torch.device("cpu")
    print("cpu mode")
# Out:
# gpu mode

# %%
# the name of results files
codename = 'kd_example'

fnnname = codename + "_fnn_model"

total_loss_name = codename + "_total_loss"
soft_loss_name = codename + "_soft_loss"
tri_loss_name = codename + "_tri_loss"
acc_name = codename + "_accuracy"

result_name = codename + "_result"

# %%
class Datasets(object):
    def __init__(self, dataset_name, batch_size = 100, num_workers = 2, transform = None, shuffle = True):
        self.dataset_name = dataset_name
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.transform = transform
        self.shuffle = shuffle
        
    def create(self, path = None):
        print("Dataset :",self.dataset_name)
        if self.transform is None:
                self.transform = transforms.Compose([transforms.ToTensor()])
        
        
        if path is None:
            path = "./"+self.dataset_name+"Dataset/data"
        
        
        if self.dataset_name == "MNIST":
            trainset = torchvision.datasets.MNIST(root = path,
                                       train = True, download = True, transform = self.transform)
            testset = torchvision.datasets.MNIST(root = path,
                                                 train = False, download = True, transform = self.transform)
            classes = list(range(10))
            base_labels = trainset.classes
            
        elif self.dataset_name == "FashionMNIST":
            trainset = torchvision.datasets.FashionMNIST(root = path,
                                       train = True, download = True, transform = self.transform)
            testset = torchvision.datasets.FashionMNIST(root = path,
                                                 train = False, download = True, transform = self.transform)
            classes = list(range(10))
            base_labels = trainset.classes
            
        elif self.dataset_name == "CIFAR10":
            trainset = torchvision.datasets.CIFAR10(root = path,
                                       train = True, download = True, transform = self.transform)
            testset = torchvision.datasets.CIFAR10(root = path,
                                                 train = False, download = True, transform = self.transform)
            classes = list(range(10))
            base_labels = trainset.classes
            
        elif self.dataset_name == "CIFAR100":
            trainset = torchvision.datasets.CIFAR100(root = path,
                                       train = True, download = True, transform = self.transform)
            testset = torchvision.datasets.CIFAR100(root = path,
                                                 train = False, download = True, transform = self.transform)
            classes = list(range(100))
            base_labels = trainset.classes
        
        else:
            raise KeyError("Unknown dataset: {}".format(self.dataset_name))
            
        
        trainloader = torch.utils.data.DataLoader(trainset, batch_size = self.batch_size,
                        shuffle = self.shuffle, num_workers = self.num_workers)
        
        if testset is not None:
            testloader = torch.utils.data.DataLoader(testset, batch_size = self.batch_size,
                        shuffle = False, num_workers = self.num_workers)
        else:
            testloader = None
            
            
        return [trainloader, testloader, classes, base_labels, trainset, testset]
    
    def worker_init_fn(self, worker_id):                                                          
        np.random.seed(worker_id)

# %%
# load the data set
instance_datasets = Datasets(DATASET, BATCH_SIZE, NUM_WORKERS, shuffle = False)
data_sets = instance_datasets.create()

#trainloader = data_sets[0]
#testloader = data_sets[1]
classes = data_sets[2]
based_labels = data_sets[3]
trainset = data_sets[4]
testset = data_sets[5]
# Out:
# Dataset : CIFAR10
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class KDTripletDataset(torch.utils.data.Dataset):
    def __init__(self, dataset):
        self.dataset = dataset
        
        data = dataset.data
        labels = dataset.targets
        if type(labels) is not torch.Tensor:
                labels = torch.tensor(labels)
        
        # make label set 0-9
        labels_set = set(labels.numpy())
        
        # make the indices excepted each classes
        label_to_indices = {label : np.where(labels.numpy() != label)[0] for label in labels_set}
        
        if self.dataset.train:
            self.negative_indices = label_to_indices
        else:
            self.negative_indices = [[np.random.choice(label_to_indices[labels[i].item()])] for i in range(len(data))]
        

            
    def __getitem__(self, index):
        if self.dataset.train:
            img1_2, label1_2 = self.dataset[index]
            if type(label1_2) is not torch.Tensor:
                label1_2 = torch.tensor(label1_2)
            img3, label3 = self.dataset[np.random.choice(self.negative_indices[label1_2.item()])]
        else:
            img1_2, label1_2 = self.dataset[index]
            img3, label3 = self.dataset[self.negative_indices[index][0]]
        
            
        return (img1_2, img3), (label1_2, label3)
    
    def __len__(self):
        return len(self.dataset)

# %%
# use the KD Triplet Dataset by using above dataset
tri_trainset = KDTripletDataset(trainset)
tri_testset = KDTripletDataset(testset)
tri_trainloader = torch.utils.data.DataLoader(tri_trainset, batch_size = BATCH_SIZE, shuffle = True, num_workers = NUM_WORKERS)
tri_testloader = torch.utils.data.DataLoader(tri_testset, batch_size = BATCH_SIZE, shuffle = False, num_workers = NUM_WORKERS)

# %%
class Net_teacher(nn.Module):
    def __init__(self):
        super(Net_teacher, self).__init__()
        self.conv1 = nn.Conv2d(3,32,3, padding=1)
        self.conv2 = nn.Conv2d(32,32,3, padding=1)
        self.conv3 = nn.Conv2d(32,64, 3, padding=1)
        self.conv4 = nn.Conv2d(64,64, 3, padding=1)
        self.conv5 = nn.Conv2d(64,128, 3, padding=1)
        self.fc1 = nn.Linear(128*4*4, 512)
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, 10)

        self.batchnorm1 = nn.BatchNorm2d(32)
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.batchnorm3 = nn.BatchNorm2d(64)
        self.batchnorm4 = nn.BatchNorm2d(64)
        self.batchnorm5 = nn.BatchNorm2d(128)

        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(p=0.5)
        self.relu = nn.ReLU()


    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.batchnorm1(x)
        x = self.pool(x)
        x = self.relu(self.conv2(x))
        x = self.batchnorm2(x)
        x = self.pool(x)

        x = self.relu(self.conv3(x))
        x = self.batchnorm3(x)
        x = self.relu(self.conv4(x))
        x = self.batchnorm4(x)
        x = self.relu(self.conv5(x))
        x = self.batchnorm5(x)
        x = self.pool(x)

        x = x.view(-1, 128 * 4 * 4)
        x = self.dropout(self.relu(self.fc1(x)))
        x = self.dropout(self.relu(self.fc2(x)))
        x = self.fc3(x)
        return x


class Net_student(nn.Module):
    def __init__(self):
        super(Net_student, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 32, 3, padding=1)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
        self.fc1 = nn.Linear(64 * 4 * 4, 128)
        self.fc2 = nn.Linear(128, 10)

        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(p=0.5)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.pool(x)

        x = self.relu(self.conv2(x))
        x = self.pool(x)

        x = self.relu(self.conv3(x))
        x = self.pool(x)
        
        x = x.view(-1, 64 * 4 * 4)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# network and criterions
model_t = Net_teacher().to(device)
model_s = Net_student().to(device)

model_t.load_state_dict(torch.load("cnn_alex.pkl"))

optimizer = optim.SGD(model_s.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=SCHEDULER_STEPS, gamma=SCHEDULER_GAMMA)

soft_criterion = nn.CrossEntropyLoss()
triplet_loss = nn.TripletMarginLoss(margin=TRIPLET_MARGINE)

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
class NetworkFit(object):
    def __init__(self, model_t, model_s, optimizer, soft_criterion, triplet_loss):
        self.model_t = model_t
        self.model_s = model_s
        self.optimizer = optimizer
        
        self.soft_criterion = soft_criterion
        self.triplet_loss = triplet_loss
        
        self.model_t.eval()
        

    def train(self, inputs, labels, kd_lambda = 2.0):
        self.optimizer.zero_grad()
        self.model_s.train()

        img1_t = inputs[0]
        img2_s = inputs[1]
        img3_s = inputs[2]
        
        label1_t = labels[0]
        label2_s = labels[1]
        label3_s = labels[2]
        
        out1_t = self.model_t(img1_t)
        out2_s = self.model_s(img2_s)
        out3_s = self.model_s(img3_s)
        
        soft_loss = self.soft_criterion(out2_s, label2_s)
        trip_loss = self.triplet_loss(out1_t, out2_s, out3_s)

        loss = soft_loss + kd_lambda*trip_loss

        loss.backward()
        self.optimizer.step()
            
            
    def test(self, inputs, labels, kd_lambda = 2.0):
        self.model_s.eval()
        
        img1_t = inputs[0]
        img2_s = inputs[1]
        img3_s = inputs[2]
        
        label1_t = labels[0]
        label2_s = labels[1]
        label3_s = labels[2]
        
        out1_t = self.model_t(img1_t)
        out2_s = self.model_s(img2_s)
        out3_s = self.model_s(img3_s)
        
        soft_loss = self.soft_criterion(out2_s, label2_s)
        trip_loss = self.triplet_loss(out1_t, out2_s, out3_s)

        loss = soft_loss + kd_lambda*trip_loss
        
        _, predicted = out2_s.max(1)
        correct = (predicted == label2_s).sum().item()
        
        return [loss.item(), soft_loss.item(), trip_loss.item()], [correct]

# %%
# fit for training and test
fit = NetworkFit(model_t, model_s, optimizer, soft_criterion, triplet_loss)

# %%
class Score(object):
    def __init__(self, score = 0):
        self.score = score
        
    def sum_score(self, score):
        self.score += score
    
    def set_score(self, score):
        self.score = score
    
    def init_score(self):
        self.score = 0
    
    def get_score(self):
        return self.score

# %%
class ScoreCalc(object):
    def __init__(self, losses, corrects, batch_size):
        self.losses = losses
        self.corrects = corrects
        
        self.batch_size = batch_size
        
        self.len_l = len(losses)
        self.len_c = len(corrects)
        
        self.train_losses = [[] for l in range(self.len_l)]
        self.train_corrects = [[] for c in range(self.len_c)]
        
        self.test_losses = [[] for l in range(self.len_l)]
        self.test_corrects = [[] for c in range(self.len_c)]

        patience = 50

        self.early_stopping = EarlyStopping(patience=patience, verbose=True)
       
    
    def calc_sum(self, losses, corrects):
        if len(losses) != len(self.losses):
            print("warning : len(losses) != len(self.losses)")
            sys.exit()
        if len(corrects) != len(self.corrects):
            print("warning : len(corrects) != len(self.corrects)")
            sys.exit()
        
        for l in range(self.len_l):
            self.losses[l].sum_score(losses[l])
        
        for c in range(self.len_c):
            self.corrects[c].sum_score(corrects[c])
        
        return self.losses, self.corrects
    
    
    def score_del(self):
        for loss in self.losses:
            loss.init_score()
        for correct in self.corrects:
            correct.init_score()

        
    def score_print(self, data_num, train = True):
        if train:
            print("train mean loss={}, accuracy={}".format(self.losses[0].get_score()*self.batch_size/data_num, float(self.corrects[0].get_score()/data_num)))
        else:
            
            print("test mean loss={}, accuracy={}".format(self.losses[0].get_score()*self.batch_size/data_num, float(self.corrects[0].get_score()/data_num)))
            self.early_stopping(self.losses[0].get_score()*self.batch_size/data_num, model_s)
        
            if self.early_stopping.early_stop:
                print("Early stopping")
                return True
            else:
              return False

            
    def score_append(self, data_num, train = True):
        if train:
            for l in range(self.len_l):
                self.train_losses[l].append(self.losses[l].get_score()*self.batch_size/data_num)
            for c in range(self.len_c):
                self.train_corrects[c].append(float(self.corrects[c].get_score()/data_num))
        else:
            for l in range(self.len_l):
                self.test_losses[l].append(self.losses[l].get_score()*self.batch_size/data_num)
            for c in range(self.len_c):
                self.test_corrects[c].append(float(self.corrects[c].get_score()/data_num))
    
    
    def get_value(self, train = True):
        if train:
            return self.train_losses, self.train_corrects
        else:
            return self.test_losses, self.test_corrects

# %%
# to manage all scores
loss = Score()
loss_s = Score()
loss_t = Score()
correct = Score()
score_loss = [loss, loss_s, loss_t]
score_correct = [correct]
sc = ScoreCalc(score_loss, score_correct, BATCH_SIZE)

# %%
# training and test
for epoch in range(EPOCH):
    print('epoch', epoch+1)
    
    c = 0
    for (inputs, labels) in tri_trainloader:
        c+=1
        print("\rIteration: {}/{}".format(c, len(tri_trainloader)), end="")
        img1_t = inputs[0].to(device)
        img2_s = inputs[0].to(device)
        img3_s = inputs[1].to(device)
        
        images = (img1_t, img2_s, img3_s)
        
        label1_t = labels[0].to(device)
        label2_s = labels[0].to(device)
        label3_s = labels[1].to(device)
        
        label = (label1_t, label2_s, label3_s)
        
        fit.train(images, label, KD_LAMBDA)
    c = 0
    print("Train Loss Calc")
    for (inputs, labels) in tri_trainloader:
        c+=1
        print("\rIteration: {}/{}".format(c, len(tri_trainloader)), end="")
        img1_t = inputs[0].to(device)
        img2_s = inputs[0].to(device)
        img3_s = inputs[1].to(device)
        
        images = (img1_t, img2_s, img3_s)
        
        label1_t = labels[0].to(device)
        label2_s = labels[0].to(device)
        label3_s = labels[1].to(device)
        
        label = (label1_t, label2_s, label3_s)
        
        losses, corrects = fit.test(images, label, KD_LAMBDA)
        
        sc.calc_sum(losses, corrects)
    
    sc.score_print(len(trainset))
    sc.score_append(len(trainset))
    sc.score_del()
    c = 0
    print("Test Loss Calc")
    for (inputs, labels) in tri_testloader:
        c+=1
        
        print("\rIteration: {}/{}".format(c, len(tri_testloader)), end="")
        img1_t = inputs[0].to(device)
        img2_s = inputs[0].to(device)
        img3_s = inputs[1].to(device)
        
        images = (img1_t, img2_s, img3_s)
        
        label1_t = labels[0].to(device)
        label2_s = labels[0].to(device)
        label3_s = labels[1].to(device)
        
        label = (label1_t, label2_s, label3_s)
        
        losses, corrects = fit.test(images, label, KD_LAMBDA)
        
        sc.calc_sum(losses, corrects)
    
    if sc.score_print(len(testset), train = False):
      sc.score_append(len(testset), train = False)
      sc.score_del()
      break

    sc.score_append(len(testset), train = False)
    sc.score_del()
    
    scheduler.step()
# Out:
# epoch 1
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=6.488371030807495, accuracy=0.45498
# Test Loss Calc
# Iteration: 100/100test mean loss=6.4390854644775395, accuracy=0.4573
# Validation loss decreased (inf --> 6.439085).  Saving model ...
# epoch 2
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=5.101740472316742, accuracy=0.57018
# Test Loss Calc
# Iteration: 100/100test mean loss=5.228070287704468, accuracy=0.5644
# Validation loss decreased (6.439085 --> 5.228070).  Saving model ...
# epoch 3
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=4.518249933719635, accuracy=0.62788
# Test Loss Calc
# Iteration: 100/100test mean loss=4.66085821390152, accuracy=0.6186
# Validation loss decreased (5.228070 --> 4.660858).  Saving model ...
# epoch 4
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=4.079832461357117, accuracy=0.67084
# Test Loss Calc
# Iteration: 100/100test mean loss=4.296921043395996, accuracy=0.6567
# Validation loss decreased (4.660858 --> 4.296921).  Saving model ...
# epoch 5
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=4.6559998660087585, accuracy=0.62542
# Test Loss Calc
# Iteration: 100/100test mean loss=4.911221897602081, accuracy=0.6066
# EarlyStopping counter: 1 out of 50
# epoch 6
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.6075359988212585, accuracy=0.69882
# Test Loss Calc
# Iteration: 100/100test mean loss=3.9657747960090637, accuracy=0.6702
# Validation loss decreased (4.296921 --> 3.965775).  Saving model ...
# epoch 7
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.645796106338501, accuracy=0.70004
# Test Loss Calc
# Iteration: 100/100test mean loss=3.9940530490875243, accuracy=0.6723
# EarlyStopping counter: 1 out of 50
# epoch 8
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.3874507331848145, accuracy=0.7189
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7710547161102297, accuracy=0.6834
# Validation loss decreased (3.965775 --> 3.771055).  Saving model ...
# epoch 9
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.45946861743927, accuracy=0.70568
# Test Loss Calc
# Iteration: 100/100test mean loss=3.8533801865577697, accuracy=0.675
# EarlyStopping counter: 1 out of 50
# epoch 10
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.4010618438720703, accuracy=0.7162
# Test Loss Calc
# Iteration: 100/100test mean loss=3.886707603931427, accuracy=0.6795
# EarlyStopping counter: 2 out of 50
# epoch 11
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.2056221203804016, accuracy=0.7409
# Test Loss Calc
# Iteration: 100/100test mean loss=3.6360342955589293, accuracy=0.7023
# Validation loss decreased (3.771055 --> 3.636034).  Saving model ...
# epoch 12
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.06249627494812, accuracy=0.74912
# Test Loss Calc
# Iteration: 100/100test mean loss=3.485771961212158, accuracy=0.7114
# Validation loss decreased (3.636034 --> 3.485772).  Saving model ...
# epoch 13
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.3335672793388365, accuracy=0.74082
# Test Loss Calc
# Iteration: 100/100test mean loss=3.786013069152832, accuracy=0.6961
# EarlyStopping counter: 1 out of 50
# epoch 14
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9459409713745117, accuracy=0.7586
# Test Loss Calc
# Iteration: 100/100test mean loss=3.4009916162490845, accuracy=0.7156
# Validation loss decreased (3.485772 --> 3.400992).  Saving model ...
# epoch 15
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.2203870778083803, accuracy=0.7228
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7242543935775756, accuracy=0.6847
# EarlyStopping counter: 1 out of 50
# epoch 16
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.003231833934784, accuracy=0.7479
# Test Loss Calc
# Iteration: 100/100test mean loss=3.471312301158905, accuracy=0.6984
# EarlyStopping counter: 2 out of 50
# epoch 17
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9735644617080688, accuracy=0.75574
# Test Loss Calc
# Iteration: 100/100test mean loss=3.474525785446167, accuracy=0.7137
# EarlyStopping counter: 3 out of 50
# epoch 18
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.6631592576503755, accuracy=0.77732
# Test Loss Calc
# Iteration: 100/100test mean loss=3.153437945842743, accuracy=0.7324
# Validation loss decreased (3.400992 --> 3.153438).  Saving model ...
# epoch 19
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.96085586643219, accuracy=0.76006
# Test Loss Calc
# Iteration: 100/100test mean loss=3.4734408688545226, accuracy=0.7112
# EarlyStopping counter: 1 out of 50
# epoch 20
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8483194403648375, accuracy=0.76216
# Test Loss Calc
# Iteration: 100/100test mean loss=3.3450595140457153, accuracy=0.7136
# EarlyStopping counter: 2 out of 50
# epoch 21
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.004927463054657, accuracy=0.75398
# Test Loss Calc
# Iteration: 100/100test mean loss=3.4712025690078736, accuracy=0.7054
# EarlyStopping counter: 3 out of 50
# epoch 22
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.841465453147888, accuracy=0.75878
# Test Loss Calc
# Iteration: 100/100test mean loss=3.3675322198867796, accuracy=0.7156
# EarlyStopping counter: 4 out of 50
# epoch 23
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0374265184402467, accuracy=0.7516
# Test Loss Calc
# Iteration: 100/100test mean loss=3.5386923861503603, accuracy=0.7082
# EarlyStopping counter: 5 out of 50
# epoch 24
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8597518045902253, accuracy=0.76222
# Test Loss Calc
# Iteration: 100/100test mean loss=3.3527609634399416, accuracy=0.7152
# EarlyStopping counter: 6 out of 50
# epoch 25
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.1490161089897155, accuracy=0.74706
# Test Loss Calc
# Iteration: 100/100test mean loss=3.6711352467536926, accuracy=0.7091
# EarlyStopping counter: 7 out of 50
# epoch 26
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.69530295920372, accuracy=0.78048
# Test Loss Calc
# Iteration: 100/100test mean loss=3.1972877311706545, accuracy=0.7323
# EarlyStopping counter: 8 out of 50
# epoch 27
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.7084435641765596, accuracy=0.77442
# Test Loss Calc
# Iteration: 100/100test mean loss=3.271083152294159, accuracy=0.7231
# EarlyStopping counter: 9 out of 50
# epoch 28
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8795085809230803, accuracy=0.76476
# Test Loss Calc
# Iteration: 100/100test mean loss=3.3935200476646425, accuracy=0.7145
# EarlyStopping counter: 10 out of 50
# epoch 29
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.758786901473999, accuracy=0.77216
# Test Loss Calc
# Iteration: 100/100test mean loss=3.249658043384552, accuracy=0.7242
# EarlyStopping counter: 11 out of 50
# epoch 30
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.7262682857513427, accuracy=0.7776
# Test Loss Calc
# Iteration: 100/100test mean loss=3.2759180879592895, accuracy=0.7316
# EarlyStopping counter: 12 out of 50
# epoch 31
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.482219047307968, accuracy=0.79726
# Test Loss Calc
# Iteration: 100/100test mean loss=3.036364152431488, accuracy=0.7461
# Validation loss decreased (3.153438 --> 3.036364).  Saving model ...
# epoch 32
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.907323567390442, accuracy=0.76932
# Test Loss Calc
# Iteration: 100/100test mean loss=3.413583390712738, accuracy=0.7281
# EarlyStopping counter: 1 out of 50
# epoch 33
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.6567452974319457, accuracy=0.78614
# Test Loss Calc
# Iteration: 100/100test mean loss=3.157947504520416, accuracy=0.7399
# EarlyStopping counter: 2 out of 50
# epoch 34
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8515185017585756, accuracy=0.76914
# Test Loss Calc
# Iteration: 100/100test mean loss=3.376474344730377, accuracy=0.7273
# EarlyStopping counter: 3 out of 50
# epoch 35
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.734136913537979, accuracy=0.78008
# Test Loss Calc
# Iteration: 100/100test mean loss=3.314646668434143, accuracy=0.7323
# EarlyStopping counter: 4 out of 50
# epoch 36
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.7277489817142486, accuracy=0.7769
# Test Loss Calc
# Iteration: 100/100test mean loss=3.260294930934906, accuracy=0.7259
# EarlyStopping counter: 5 out of 50
# epoch 37
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.499296494960785, accuracy=0.8004
# Test Loss Calc
# Iteration: 100/100test mean loss=3.034727191925049, accuracy=0.7473
# Validation loss decreased (3.036364 --> 3.034727).  Saving model ...
# epoch 38
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.639820502281189, accuracy=0.78386
# Test Loss Calc
# Iteration: 100/100test mean loss=3.1533086824417116, accuracy=0.7398
# EarlyStopping counter: 1 out of 50
# epoch 39
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.1165405337810514, accuracy=0.74778
# Test Loss Calc
# Iteration: 100/100test mean loss=3.6014816403388976, accuracy=0.7053
# EarlyStopping counter: 2 out of 50
# epoch 40
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.6217610001564027, accuracy=0.78896
# Test Loss Calc
# Iteration: 100/100test mean loss=3.148874595165253, accuracy=0.7389
# EarlyStopping counter: 3 out of 50
# epoch 41
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.4959223108291626, accuracy=0.7964
# Test Loss Calc
# Iteration: 100/100test mean loss=3.064049108028412, accuracy=0.7451
# EarlyStopping counter: 4 out of 50
# epoch 42
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0016225543022155, accuracy=0.74886
# Test Loss Calc
# Iteration: 100/100test mean loss=3.4786223340034486, accuracy=0.7126
# EarlyStopping counter: 5 out of 50
# epoch 43
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.7462163708209992, accuracy=0.76826
# Test Loss Calc
# Iteration: 100/100test mean loss=3.277534239292145, accuracy=0.7281
# EarlyStopping counter: 6 out of 50
# epoch 44
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9603476934432984, accuracy=0.7657
# Test Loss Calc
# Iteration: 100/100test mean loss=3.489745898246765, accuracy=0.7194
# EarlyStopping counter: 7 out of 50
# epoch 45
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.6176689448356627, accuracy=0.72102
# Test Loss Calc
# Iteration: 100/100test mean loss=4.145666363239289, accuracy=0.6775
# EarlyStopping counter: 8 out of 50
# epoch 46
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.5461710729599, accuracy=0.79714
# Test Loss Calc
# Iteration: 100/100test mean loss=3.111846055984497, accuracy=0.753
# EarlyStopping counter: 9 out of 50
# epoch 47
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.067016466140747, accuracy=0.75784
# Test Loss Calc
# Iteration: 100/100test mean loss=3.6042859315872193, accuracy=0.7099
# EarlyStopping counter: 10 out of 50
# epoch 48
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.944227171897888, accuracy=0.75802
# Test Loss Calc
# Iteration: 100/100test mean loss=3.514730603694916, accuracy=0.7165
# EarlyStopping counter: 11 out of 50
# epoch 49
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.5994793946743013, accuracy=0.79162
# Test Loss Calc
# Iteration: 100/100test mean loss=3.111535756587982, accuracy=0.7488
# EarlyStopping counter: 12 out of 50
# epoch 50
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.817860485315323, accuracy=0.7732
# Test Loss Calc
# Iteration: 100/100test mean loss=3.389474709033966, accuracy=0.7276
# EarlyStopping counter: 13 out of 50
# epoch 51
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.666354253292084, accuracy=0.7866
# Test Loss Calc
# Iteration: 100/100test mean loss=3.2428832387924196, accuracy=0.7333
# EarlyStopping counter: 14 out of 50
# epoch 52
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8742004356384276, accuracy=0.76984
# Test Loss Calc
# Iteration: 100/100test mean loss=3.402357461452484, accuracy=0.7171
# EarlyStopping counter: 15 out of 50
# epoch 53
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.6429001393318177, accuracy=0.78908
# Test Loss Calc
# Iteration: 100/100test mean loss=3.175951988697052, accuracy=0.7442
# EarlyStopping counter: 16 out of 50
# epoch 54
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.966057054042816, accuracy=0.76194
# Test Loss Calc
# Iteration: 100/100test mean loss=3.515072147846222, accuracy=0.7141
# EarlyStopping counter: 17 out of 50
# epoch 55
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.844208703994751, accuracy=0.77626
# Test Loss Calc
# Iteration: 100/100test mean loss=3.3748218035697937, accuracy=0.7295
# EarlyStopping counter: 18 out of 50
# epoch 56
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.72223730969429, accuracy=0.77592
# Test Loss Calc
# Iteration: 100/100test mean loss=3.257144706249237, accuracy=0.7277
# EarlyStopping counter: 19 out of 50
# epoch 57
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.66157835149765, accuracy=0.78478
# Test Loss Calc
# Iteration: 100/100test mean loss=3.2220732879638674, accuracy=0.7312
# EarlyStopping counter: 20 out of 50
# epoch 58
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.5912789695262908, accuracy=0.78752
# Test Loss Calc
# Iteration: 100/100test mean loss=3.2000818991661073, accuracy=0.738
# EarlyStopping counter: 21 out of 50
# epoch 59
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8013151857852936, accuracy=0.77636
# Test Loss Calc
# Iteration: 100/100test mean loss=3.3911597776412963, accuracy=0.723
# EarlyStopping counter: 22 out of 50
# epoch 60
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9038680186271666, accuracy=0.76336
# Test Loss Calc
# Iteration: 100/100test mean loss=3.453105528354645, accuracy=0.7137
# EarlyStopping counter: 23 out of 50
# epoch 61
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.4642831399440763, accuracy=0.80098
# Test Loss Calc
# Iteration: 100/100test mean loss=2.9643289613723756, accuracy=0.7569
# Validation loss decreased (3.034727 --> 2.964329).  Saving model ...
# epoch 62
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.5930783767700194, accuracy=0.79074
# Test Loss Calc
# Iteration: 100/100test mean loss=3.1334730625152587, accuracy=0.7431
# EarlyStopping counter: 1 out of 50
# epoch 63
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.754630142688751, accuracy=0.79042
# Test Loss Calc
# Iteration: 100/100test mean loss=3.2705730605125427, accuracy=0.742
# EarlyStopping counter: 2 out of 50
# epoch 64
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.6124775977134704, accuracy=0.7941
# Test Loss Calc
# Iteration: 100/100test mean loss=3.215774998664856, accuracy=0.7479
# EarlyStopping counter: 3 out of 50
# epoch 65
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.6690084340572358, accuracy=0.7882
# Test Loss Calc
# Iteration: 100/100test mean loss=3.1936340355873107, accuracy=0.7396
# EarlyStopping counter: 4 out of 50
# epoch 66
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.5240388617515563, accuracy=0.79996
# Test Loss Calc
# Iteration: 100/100test mean loss=3.0966327738761903, accuracy=0.7438
# EarlyStopping counter: 5 out of 50
# epoch 67
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.595791800737381, accuracy=0.78872
# Test Loss Calc
# Iteration: 100/100test mean loss=3.1612640476226805, accuracy=0.7327
# EarlyStopping counter: 6 out of 50
# epoch 68
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.685745890378952, accuracy=0.78026
# Test Loss Calc
# Iteration: 100/100test mean loss=3.203056261539459, accuracy=0.7343
# EarlyStopping counter: 7 out of 50
# epoch 69
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.7971899337768553, accuracy=0.7762
# Test Loss Calc
# Iteration: 100/100test mean loss=3.3516035962104795, accuracy=0.7225
# EarlyStopping counter: 8 out of 50
# epoch 70
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.4985981373786927, accuracy=0.80016
# Test Loss Calc
# Iteration: 100/100test mean loss=3.0220175838470458, accuracy=0.7529
# EarlyStopping counter: 9 out of 50
# epoch 71
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.7113001449108123, accuracy=0.77848
# Test Loss Calc
# Iteration: 100/100test mean loss=3.2481325268745422, accuracy=0.73
# EarlyStopping counter: 10 out of 50
# epoch 72
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.5643739671707153, accuracy=0.79272
# Test Loss Calc
# Iteration: 100/100test mean loss=3.143607475757599, accuracy=0.7427
# EarlyStopping counter: 11 out of 50
# epoch 73
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.59882865023613, accuracy=0.79344
# Test Loss Calc
# Iteration: 100/100test mean loss=3.153661539554596, accuracy=0.743
# EarlyStopping counter: 12 out of 50
# epoch 74
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.6173572018146514, accuracy=0.79164
# Test Loss Calc
# Iteration: 100/100test mean loss=3.128058681488037, accuracy=0.7406
# EarlyStopping counter: 13 out of 50
# epoch 75
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8112648239135742, accuracy=0.77624
# Test Loss Calc
# Iteration: 100/100test mean loss=3.3253747844696044, accuracy=0.7272
# EarlyStopping counter: 14 out of 50
# epoch 76
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.5574628202915193, accuracy=0.7909
# Test Loss Calc
# Iteration: 100/100test mean loss=3.1075392246246336, accuracy=0.7353
# EarlyStopping counter: 15 out of 50
# epoch 77
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.4821905620098113, accuracy=0.80026
# Test Loss Calc
# Iteration: 100/100test mean loss=3.1079026317596434, accuracy=0.7486
# EarlyStopping counter: 16 out of 50
# epoch 78
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.718136586666107, accuracy=0.78592
# Test Loss Calc
# Iteration: 100/100test mean loss=3.306021063327789, accuracy=0.7403
# EarlyStopping counter: 17 out of 50
# epoch 79
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.417985892057419, accuracy=0.80314
# Test Loss Calc
# Iteration: 100/100test mean loss=3.0045705032348633, accuracy=0.7507
# EarlyStopping counter: 18 out of 50
# epoch 80
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.6458418333530425, accuracy=0.78046
# Test Loss Calc
# Iteration: 100/100test mean loss=3.1789985203742983, accuracy=0.7365
# EarlyStopping counter: 19 out of 50
# epoch 81
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.6712713453769683, accuracy=0.78896
# Test Loss Calc
# Iteration: 100/100test mean loss=3.2357518243789674, accuracy=0.7386
# EarlyStopping counter: 20 out of 50
# epoch 82
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.5037800159454346, accuracy=0.79984
# Test Loss Calc
# Iteration: 100/100test mean loss=3.064049496650696, accuracy=0.7488
# EarlyStopping counter: 21 out of 50
# epoch 83
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.557202148914337, accuracy=0.79726
# Test Loss Calc
# Iteration: 100/100test mean loss=3.107592487335205, accuracy=0.7515
# EarlyStopping counter: 22 out of 50
# epoch 84
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.5904783823490143, accuracy=0.78542
# Test Loss Calc
# Iteration: 100/100test mean loss=3.158517453670502, accuracy=0.7369
# EarlyStopping counter: 23 out of 50
# epoch 85
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.688894733667374, accuracy=0.78576
# Test Loss Calc
# Iteration: 100/100test mean loss=3.2297276711463927, accuracy=0.739
# EarlyStopping counter: 24 out of 50
# epoch 86
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.859047092437744, accuracy=0.76594
# Test Loss Calc
# Iteration: 100/100test mean loss=3.3915225434303284, accuracy=0.7155
# EarlyStopping counter: 25 out of 50
# epoch 87
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9940139379501343, accuracy=0.7543
# Test Loss Calc
# Iteration: 100/100test mean loss=3.5445329308509828, accuracy=0.7113
# EarlyStopping counter: 26 out of 50
# epoch 88
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.1214238572120667, accuracy=0.73968
# Test Loss Calc
# Iteration: 100/100test mean loss=3.645694763660431, accuracy=0.6929
# EarlyStopping counter: 27 out of 50
# epoch 89
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.683896763086319, accuracy=0.78328
# Test Loss Calc
# Iteration: 100/100test mean loss=3.193180959224701, accuracy=0.7364
# EarlyStopping counter: 28 out of 50
# epoch 90
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.950899161338806, accuracy=0.7685
# Test Loss Calc
# Iteration: 100/100test mean loss=3.490560417175293, accuracy=0.724
# EarlyStopping counter: 29 out of 50
# epoch 91
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.7076342837810516, accuracy=0.77626
# Test Loss Calc
# Iteration: 100/100test mean loss=3.24811283826828, accuracy=0.7242
# EarlyStopping counter: 30 out of 50
# epoch 92
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8181295833587647, accuracy=0.78368
# Test Loss Calc
# Iteration: 100/100test mean loss=3.375928471088409, accuracy=0.7391
# EarlyStopping counter: 31 out of 50
# epoch 93
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.626252749681473, accuracy=0.79188
# Test Loss Calc
# Iteration: 100/100test mean loss=3.179645848274231, accuracy=0.7417
# EarlyStopping counter: 32 out of 50
# epoch 94
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.5305788478851317, accuracy=0.79616
# Test Loss Calc
# Iteration: 100/100test mean loss=3.1023937702178954, accuracy=0.7412
# EarlyStopping counter: 33 out of 50
# epoch 95
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.7422403557300568, accuracy=0.77952
# Test Loss Calc
# Iteration: 100/100test mean loss=3.235007092952728, accuracy=0.7292
# EarlyStopping counter: 34 out of 50
# epoch 96
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.1118573055267333, accuracy=0.74788
# Test Loss Calc
# Iteration: 100/100test mean loss=3.600815010070801, accuracy=0.6969
# EarlyStopping counter: 35 out of 50
# epoch 97
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.7310389924049376, accuracy=0.79748
# Test Loss Calc
# Iteration: 100/100test mean loss=3.3449668431282045, accuracy=0.7476
# EarlyStopping counter: 36 out of 50
# epoch 98
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8763861474990846, accuracy=0.77364
# Test Loss Calc
# Iteration: 100/100test mean loss=3.397247552871704, accuracy=0.7256
# EarlyStopping counter: 37 out of 50
# epoch 99
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.740795385360718, accuracy=0.77576
# Test Loss Calc
# Iteration: 100/100test mean loss=3.308126015663147, accuracy=0.7301
# EarlyStopping counter: 38 out of 50
# epoch 100
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.555638257265091, accuracy=0.80136
# Test Loss Calc
# Iteration: 100/100test mean loss=3.1681677222251894, accuracy=0.7474
# EarlyStopping counter: 39 out of 50
# epoch 101
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.8066389811038972, accuracy=0.85168
# Test Loss Calc
# Iteration: 100/100test mean loss=2.4835415256023405, accuracy=0.7899
# Validation loss decreased (2.964329 --> 2.483542).  Saving model ...
# epoch 102
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.731863708257675, accuracy=0.85932
# Test Loss Calc
# Iteration: 100/100test mean loss=2.4273621368408205, accuracy=0.7967
# Validation loss decreased (2.483542 --> 2.427362).  Saving model ...
# epoch 103
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.6643190495967866, accuracy=0.8659
# Test Loss Calc
# Iteration: 100/100test mean loss=2.39511239528656, accuracy=0.7995
# Validation loss decreased (2.427362 --> 2.395112).  Saving model ...
# epoch 104
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.6296190872192382, accuracy=0.86854
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3526018166542055, accuracy=0.8036
# Validation loss decreased (2.395112 --> 2.352602).  Saving model ...
# epoch 105
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.593693876504898, accuracy=0.87418
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3360882008075716, accuracy=0.8028
# Validation loss decreased (2.352602 --> 2.336088).  Saving model ...
# epoch 106
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5980384271144867, accuracy=0.87582
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3665697371959684, accuracy=0.8001
# EarlyStopping counter: 1 out of 50
# epoch 107
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.55987118434906, accuracy=0.87798
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3430869722366334, accuracy=0.7992
# EarlyStopping counter: 2 out of 50
# epoch 108
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.593987108707428, accuracy=0.87762
# Test Loss Calc
# Iteration: 100/100test mean loss=2.372348563671112, accuracy=0.8031
# EarlyStopping counter: 3 out of 50
# epoch 109
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.520417301774025, accuracy=0.88164
# Test Loss Calc
# Iteration: 100/100test mean loss=2.350630977153778, accuracy=0.8027
# EarlyStopping counter: 4 out of 50
# epoch 110
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5349941573143004, accuracy=0.87988
# Test Loss Calc
# Iteration: 100/100test mean loss=2.362706776857376, accuracy=0.8007
# EarlyStopping counter: 5 out of 50
# epoch 111
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.557330668091774, accuracy=0.8839
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3720617687702177, accuracy=0.8026
# EarlyStopping counter: 6 out of 50
# epoch 112
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5140110950469972, accuracy=0.88624
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3393362736701966, accuracy=0.8003
# EarlyStopping counter: 7 out of 50
# epoch 113
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4713393222093583, accuracy=0.88898
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3329867136478426, accuracy=0.8024
# Validation loss decreased (2.336088 --> 2.332987).  Saving model ...
# epoch 114
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4920807894468306, accuracy=0.88728
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3611603939533232, accuracy=0.8014
# EarlyStopping counter: 1 out of 50
# epoch 115
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5145933082103729, accuracy=0.88238
# Test Loss Calc
# Iteration: 100/100test mean loss=2.390093241930008, accuracy=0.7992
# EarlyStopping counter: 2 out of 50
# epoch 116
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4915403536558152, accuracy=0.88724
# Test Loss Calc
# Iteration: 100/100test mean loss=2.387357233762741, accuracy=0.797
# EarlyStopping counter: 3 out of 50
# epoch 117
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.49036159658432, accuracy=0.89076
# Test Loss Calc
# Iteration: 100/100test mean loss=2.380648978948593, accuracy=0.7998
# EarlyStopping counter: 4 out of 50
# epoch 118
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4544841213226318, accuracy=0.89244
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3681981027126313, accuracy=0.8024
# EarlyStopping counter: 5 out of 50
# epoch 119
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4328182793855666, accuracy=0.89684
# Test Loss Calc
# Iteration: 100/100test mean loss=2.345577871799469, accuracy=0.8054
# EarlyStopping counter: 6 out of 50
# epoch 120
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.442799378991127, accuracy=0.89438
# Test Loss Calc
# Iteration: 100/100test mean loss=2.382564958333969, accuracy=0.8037
# EarlyStopping counter: 7 out of 50
# epoch 121
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4587715970277786, accuracy=0.89496
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3786908876895905, accuracy=0.8015
# EarlyStopping counter: 8 out of 50
# epoch 122
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4124235832691192, accuracy=0.89848
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3508919966220856, accuracy=0.8046
# EarlyStopping counter: 9 out of 50
# epoch 123
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4856027699708938, accuracy=0.89236
# Test Loss Calc
# Iteration: 100/100test mean loss=2.4392633652687072, accuracy=0.7976
# EarlyStopping counter: 10 out of 50
# epoch 124
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4319233433008194, accuracy=0.90012
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3827590990066527, accuracy=0.8038
# EarlyStopping counter: 11 out of 50
# epoch 125
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.366144772529602, accuracy=0.904
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3158283269405366, accuracy=0.8065
# Validation loss decreased (2.332987 --> 2.315828).  Saving model ...
# epoch 126
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3641925489902496, accuracy=0.90464
# Test Loss Calc
# Iteration: 100/100test mean loss=2.326080688238144, accuracy=0.8035
# EarlyStopping counter: 1 out of 50
# epoch 127
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4636538877487182, accuracy=0.89614
# Test Loss Calc
# Iteration: 100/100test mean loss=2.4485314190387726, accuracy=0.7976
# EarlyStopping counter: 2 out of 50
# epoch 128
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4419348644018173, accuracy=0.89808
# Test Loss Calc
# Iteration: 100/100test mean loss=2.40996600151062, accuracy=0.8015
# EarlyStopping counter: 3 out of 50
# epoch 129
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3850457093715667, accuracy=0.89992
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3509381103515623, accuracy=0.8014
# EarlyStopping counter: 4 out of 50
# epoch 130
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3560182700157166, accuracy=0.90472
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3583987236022947, accuracy=0.8008
# EarlyStopping counter: 5 out of 50
# epoch 131
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3852612377405167, accuracy=0.90362
# Test Loss Calc
# Iteration: 100/100test mean loss=2.369676858186722, accuracy=0.8011
# EarlyStopping counter: 6 out of 50
# epoch 132
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3921595240831375, accuracy=0.90238
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3897674560546873, accuracy=0.801
# EarlyStopping counter: 7 out of 50
# epoch 133
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3943105939626694, accuracy=0.901
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3868956112861635, accuracy=0.7969
# EarlyStopping counter: 8 out of 50
# epoch 134
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3841426457166672, accuracy=0.9029
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3746717309951784, accuracy=0.7992
# EarlyStopping counter: 9 out of 50
# epoch 135
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3669238677024842, accuracy=0.90212
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3850681352615357, accuracy=0.7982
# EarlyStopping counter: 10 out of 50
# epoch 136
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4155125933885575, accuracy=0.90486
# Test Loss Calc
# Iteration: 100/100test mean loss=2.441091023683548, accuracy=0.7978
# EarlyStopping counter: 11 out of 50
# epoch 137
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.328753512740135, accuracy=0.90566
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3795282971858978, accuracy=0.8037
# EarlyStopping counter: 12 out of 50
# epoch 138
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3699820370674134, accuracy=0.9009
# Test Loss Calc
# Iteration: 100/100test mean loss=2.390228008031845, accuracy=0.7999
# EarlyStopping counter: 13 out of 50
# epoch 139
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3410805681943894, accuracy=0.90672
# Test Loss Calc
# Iteration: 100/100test mean loss=2.391618264913559, accuracy=0.7994
# EarlyStopping counter: 14 out of 50
# epoch 140
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3932449791431427, accuracy=0.90046
# Test Loss Calc
# Iteration: 100/100test mean loss=2.4478215837478636, accuracy=0.7937
# EarlyStopping counter: 15 out of 50
# epoch 141
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3229564212560654, accuracy=0.90896
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3775306165218355, accuracy=0.8036
# EarlyStopping counter: 16 out of 50
# epoch 142
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.323344449520111, accuracy=0.90878
# Test Loss Calc
# Iteration: 100/100test mean loss=2.3775234150886537, accuracy=0.8006
# EarlyStopping counter: 17 out of 50
# epoch 143
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3039958382844925, accuracy=0.91174
# Test Loss Calc
# Iteration: 100/100test mean loss=2.382228889465332, accuracy=0.8033
# EarlyStopping counter: 18 out of 50
# epoch 144
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3248909633159638, accuracy=0.91016
# Test Loss Calc
# Iteration: 100/100test mean loss=2.4105933129787447, accuracy=0.8012
# EarlyStopping counter: 19 out of 50
# epoch 145
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3614296008348465, accuracy=0.90884
# Test Loss Calc
# Iteration: 100/100test mean loss=2.4518514144420624, accuracy=0.7986
# EarlyStopping counter: 20 out of 50
# epoch 146
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3501862255334853, accuracy=0.90842
# Test Loss Calc
# Iteration: 100/100test mean loss=2.432792898416519, accuracy=0.7968
# EarlyStopping counter: 21 out of 50
# epoch 147
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3631038943529128, accuracy=0.9078
# Test Loss Calc
# Iteration: 100/100test mean loss=2.430376582145691, accuracy=0.7986
# EarlyStopping counter: 22 out of 50
# epoch 148
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3335866914987564, accuracy=0.91264
# Test Loss Calc
# Iteration: 100/100test mean loss=2.393045034408569, accuracy=0.8015
# EarlyStopping counter: 23 out of 50
# epoch 149
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3656259644031525, accuracy=0.90946
# Test Loss Calc
# Iteration: 100/100test mean loss=2.4482923090457915, accuracy=0.7981
# EarlyStopping counter: 24 out of 50
# epoch 150
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3644487730264663, accuracy=0.90898
# Test Loss Calc
# Iteration: 100/100test mean loss=2.464167455434799, accuracy=0.7979
# EarlyStopping counter: 25 out of 50

# %%
# get the scores
train_losses, train_corrects = sc.get_value()
test_losses, test_corrects = sc.get_value(train = False)

# %%
def plot_score(epoch, train_data, test_data, x_lim = None, y_lim = None, x_label = 'EPOCH', y_label = 'score', title = 'score', legend = ['train', 'test'], filename = 'test'):
    plt.figure(figsize=(6,6))
    
    if x_lim is None:
        x_lim = epoch
    if y_lim is None:
        y_lim = 1
        
    plt.plot(range(epoch), train_data)
    plt.plot(range(epoch), test_data, c='#00ff00')
    plt.xlim(0, x_lim)
    plt.ylim(0, y_lim)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.legend(legend)
    plt.title(title)
    plt.savefig(filename+'.png')
    plt.close()

    
def save_data(train_loss, test_loss, train_acc, test_acc, filename):
    with open(filename + '.txt', mode='w') as f:
        f.write("train mean loss={}\n".format(train_loss[-1]))
        f.write("test  mean loss={}\n".format(test_loss[-1]))
        f.write("train accuracy={}\n".format(train_acc[-1]))
        f.write("test  accuracy={}\n".format(test_acc[-1]))

# %%
torch.save(model_s.state_dict(), fnnname + '.pth')

# %%
save_data(train_losses[0], test_losses[0], train_corrects[0], test_corrects[0], result_name)

# %%
# output the glaphs of the scores

plot_score(150, train_losses[0], test_losses[0], y_lim = 5.0, y_label = 'LOSS', legend = ['train loss', 'test loss'], title = 'total loss', filename = total_loss_name)

plot_score(150, train_losses[1], test_losses[1], y_lim = 5.0, y_label = 'LOSS', legend = ['train loss', 'test loss'], title = 'softmax loss', filename = soft_loss_name)

plot_score(150, train_losses[2], test_losses[2], y_lim = 5.0, y_label = 'LOSS', legend = ['train loss', 'test loss'], title = 'triplet loss', filename = tri_loss_name)

plot_score(150, train_corrects[0], test_corrects[0], y_lim = 1, y_label = 'ACCURACY', legend = ['train acc', 'test acc'], title = 'accuracy', filename = acc_name)
