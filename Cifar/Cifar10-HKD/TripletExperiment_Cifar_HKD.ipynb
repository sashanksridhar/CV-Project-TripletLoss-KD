# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim

# numpy and matplotlib
import numpy as np
import matplotlib.pyplot as plt

import os
from PIL import Image
import sys
import torch.nn.functional as F

# %%
# initialize for  each parameters
DATASET = 'CIFAR10'
BATCH_SIZE = 100
NUM_WORKERS = 2

WEIGHT_DECAY = 0.007
LEARNING_RATE = 0.01
MOMENTUM = 0.9

SCHEDULER_STEPS = 100
SCHEDULER_GAMMA = 0.1

SEED = 1

EPOCH = 150

KD_LAMBDA = 2.0

TRIPLET_MARGINE = 5.0

# %%
# !pwd
# Out:
# /ssd_scratch/cvit/sashank.sridhar

# %%
# fixing the seed
torch.cuda.manual_seed_all(SEED)
torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
# check if gpu is available
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("gpu mode")
else:
    device = torch.device("cpu")
    print("cpu mode")
# Out:
# gpu mode

# %%
# the name of results files
codename = 'cifar10_hkd'

fnnname = codename + "_fnn_model"

total_loss_name = codename + "_total_loss"
soft_loss_name = codename + "_soft_loss"
tri_loss_name = codename + "_tri_loss"
acc_name = codename + "_accuracy"

result_name = codename + "_result"

# %%
class Datasets(object):
    def __init__(self, dataset_name, batch_size = 100, num_workers = 2, transform = None, shuffle = True):
        self.dataset_name = dataset_name
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.transform = transform
        self.shuffle = shuffle
        
    def create(self, path = None):
        print("Dataset :",self.dataset_name)
        if self.transform is None:
                self.transform = transforms.Compose([transforms.ToTensor()])
        
        
        if path is None:
            path = "./"+self.dataset_name+"Dataset/data"
        
        
        if self.dataset_name == "MNIST":
            trainset = torchvision.datasets.MNIST(root = path,
                                       train = True, download = True, transform = self.transform)
            testset = torchvision.datasets.MNIST(root = path,
                                                 train = False, download = True, transform = self.transform)
            classes = list(range(10))
            base_labels = trainset.classes
            
        elif self.dataset_name == "FashionMNIST":
            trainset = torchvision.datasets.FashionMNIST(root = path,
                                       train = True, download = True, transform = self.transform)
            testset = torchvision.datasets.FashionMNIST(root = path,
                                                 train = False, download = True, transform = self.transform)
            classes = list(range(10))
            base_labels = trainset.classes
            
        elif self.dataset_name == "CIFAR10":
            trainset = torchvision.datasets.CIFAR10(root = path,
                                       train = True, download = True, transform = self.transform)
            testset = torchvision.datasets.CIFAR10(root = path,
                                                 train = False, download = True, transform = self.transform)
            classes = list(range(10))
            base_labels = trainset.classes
            
        elif self.dataset_name == "CIFAR100":
            trainset = torchvision.datasets.CIFAR100(root = path,
                                       train = True, download = True, transform = self.transform)
            testset = torchvision.datasets.CIFAR100(root = path,
                                                 train = False, download = True, transform = self.transform)
            classes = list(range(100))
            base_labels = trainset.classes
        
        else:
            raise KeyError("Unknown dataset: {}".format(self.dataset_name))
            
        
        trainloader = torch.utils.data.DataLoader(trainset, batch_size = self.batch_size,
                        shuffle = self.shuffle, num_workers = self.num_workers)
        
        if testset is not None:
            testloader = torch.utils.data.DataLoader(testset, batch_size = self.batch_size,
                        shuffle = False, num_workers = self.num_workers)
        else:
            testloader = None
            
            
        return [trainloader, testloader, classes, base_labels, trainset, testset]
    
    def worker_init_fn(self, worker_id):                                                          
        np.random.seed(worker_id)

# %%
# load the data set
instance_datasets = Datasets(DATASET, BATCH_SIZE, NUM_WORKERS, shuffle = False)
data_sets = instance_datasets.create()

#trainloader = data_sets[0]
#testloader = data_sets[1]
classes = data_sets[2]
based_labels = data_sets[3]
trainset = data_sets[4]
testset = data_sets[5]
# Out:
# Dataset : CIFAR10
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class KDTripletDataset(torch.utils.data.Dataset):
    def __init__(self, dataset):
        self.dataset = dataset
        
        data = dataset.data
        labels = dataset.targets
        if type(labels) is not torch.Tensor:
                labels = torch.tensor(labels)
        
        # make label set 0-9
        labels_set = set(labels.numpy())
        
        # make the indices excepted each classes
        label_to_indices = {label : np.where(labels.numpy() != label)[0] for label in labels_set}
        
        if self.dataset.train:
            self.negative_indices = label_to_indices
        else:
            self.negative_indices = [[np.random.choice(label_to_indices[labels[i].item()])] for i in range(len(data))]
        

            
    def __getitem__(self, index):
        if self.dataset.train:
            img1_2, label1_2 = self.dataset[index]
            if type(label1_2) is not torch.Tensor:
                label1_2 = torch.tensor(label1_2)
            img3, label3 = self.dataset[np.random.choice(self.negative_indices[label1_2.item()])]
        else:
            img1_2, label1_2 = self.dataset[index]
            img3, label3 = self.dataset[self.negative_indices[index][0]]
        
            
        return (img1_2, img3), (label1_2, label3)
    
    def __len__(self):
        return len(self.dataset)

# %%
# use the KD Triplet Dataset by using above dataset
tri_trainset = KDTripletDataset(trainset)
tri_testset = KDTripletDataset(testset)
tri_trainloader = torch.utils.data.DataLoader(tri_trainset, batch_size = BATCH_SIZE, shuffle = True, num_workers = NUM_WORKERS)
tri_testloader = torch.utils.data.DataLoader(tri_testset, batch_size = BATCH_SIZE, shuffle = False, num_workers = NUM_WORKERS)

# %%
class Net_teacher(nn.Module):
    def __init__(self):
        super(Net_teacher, self).__init__()
        self.conv1 = nn.Conv2d(3,32,3, padding=1)
        self.conv2 = nn.Conv2d(32,32,3, padding=1)
        self.conv3 = nn.Conv2d(32,64, 3, padding=1)
        self.conv4 = nn.Conv2d(64,64, 3, padding=1)
        self.conv5 = nn.Conv2d(64,128, 3, padding=1)
        self.fc1 = nn.Linear(128*4*4, 512)
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, 10)

        self.batchnorm1 = nn.BatchNorm2d(32)
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.batchnorm3 = nn.BatchNorm2d(64)
        self.batchnorm4 = nn.BatchNorm2d(64)
        self.batchnorm5 = nn.BatchNorm2d(128)

        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(p=0.5)
        self.relu = nn.ReLU()


    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.batchnorm1(x)
        x = self.pool(x)
        x = self.relu(self.conv2(x))
        x = self.batchnorm2(x)
        x = self.pool(x)

        x = self.relu(self.conv3(x))
        x = self.batchnorm3(x)
        x = self.relu(self.conv4(x))
        x = self.batchnorm4(x)
        x = self.relu(self.conv5(x))
        x = self.batchnorm5(x)
        x = self.pool(x)

        x = x.view(-1, 128 * 4 * 4)
        x = self.dropout(self.relu(self.fc1(x)))
        x = self.dropout(self.relu(self.fc2(x)))
        x = self.fc3(x)
        return x


class Net_student(nn.Module):
    def __init__(self):
        super(Net_student, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 32, 3, padding=1)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
        self.fc1 = nn.Linear(64 * 4 * 4, 128)
        self.fc2 = nn.Linear(128, 10)

        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(p=0.5)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.pool(x)

        x = self.relu(self.conv2(x))
        x = self.pool(x)

        x = self.relu(self.conv3(x))
        x = self.pool(x)
        
        x = x.view(-1, 64 * 4 * 4)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# network and criterions
model_t = Net_teacher().to(device)
model_s = Net_student().to(device)

model_t.load_state_dict(torch.load("cnn_alex.pkl"))

optimizer = optim.SGD(model_s.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=SCHEDULER_STEPS, gamma=SCHEDULER_GAMMA)

soft_criterion = nn.CrossEntropyLoss()
triplet_loss = nn.TripletMarginLoss(margin=TRIPLET_MARGINE)

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
class NetworkFit(object):
    def __init__(self, model_t, model_s, optimizer, soft_criterion, triplet_loss):
        self.model_t = model_t
        self.model_s = model_s
        self.optimizer = optimizer
        
        self.soft_criterion = soft_criterion
        self.triplet_loss = triplet_loss
        
        self.model_t.eval()
        

    def train(self, inputs, labels, kd_lambda = 2.0):
        self.optimizer.zero_grad()
        self.model_s.train()

        img1_t = inputs[0]
        img2_s = inputs[1]
        img3_s = inputs[2]
        
        label1_t = labels[0]
        label2_s = labels[1]
        label3_s = labels[2]
        
        out1_t = self.model_t(img1_t)
        out2_s = self.model_s(img2_s)
        out3_s = self.model_s(img3_s)
        
        soft_loss = self.soft_criterion(out2_s, label2_s)
        trip_loss = self.triplet_loss(out1_t, out2_s, out3_s)
        
        temperature=1.0
        
        soft_log_probs = F.log_softmax(out2_s / temperature, dim=1)
        # soft_targets = F.softmax(self.cached_teacher_logits[minibatch_id] / self.temperature)
        soft_targets = F.softmax(out1_t / temperature, dim=1)

        distillation_loss = F.kl_div(soft_log_probs, soft_targets.detach(), reduction='batchmean')
        
        distillation_loss_scaled = distillation_loss * temperature ** 2

        loss = soft_loss + kd_lambda*trip_loss + distillation_loss_scaled

        loss.backward()
        self.optimizer.step()
            
            
    def test(self, inputs, labels, kd_lambda = 2.0):
        self.model_s.eval()
        
        img1_t = inputs[0]
        img2_s = inputs[1]
        img3_s = inputs[2]
        
        label1_t = labels[0]
        label2_s = labels[1]
        label3_s = labels[2]
        
        out1_t = self.model_t(img1_t)
        out2_s = self.model_s(img2_s)
        out3_s = self.model_s(img3_s)
        
        soft_loss = self.soft_criterion(out2_s, label2_s)
        trip_loss = self.triplet_loss(out1_t, out2_s, out3_s)
        
        temperature=1.0
        
        soft_log_probs = F.log_softmax(out2_s / temperature, dim=1)
        # soft_targets = F.softmax(self.cached_teacher_logits[minibatch_id] / self.temperature)
        soft_targets = F.softmax(out1_t / temperature, dim=1)

        distillation_loss = F.kl_div(soft_log_probs, soft_targets.detach(), reduction='batchmean')
        
        distillation_loss_scaled = distillation_loss * temperature ** 2

        loss = soft_loss + kd_lambda*trip_loss + distillation_loss_scaled
        
        _, predicted = out2_s.max(1)
        correct = (predicted == label2_s).sum().item()
        
        return [loss.item(), soft_loss.item(), trip_loss.item()], [correct]

# %%
# fit for training and test
fit = NetworkFit(model_t, model_s, optimizer, soft_criterion, triplet_loss)

# %%
class Score(object):
    def __init__(self, score = 0):
        self.score = score
        
    def sum_score(self, score):
        self.score += score
    
    def set_score(self, score):
        self.score = score
    
    def init_score(self):
        self.score = 0
    
    def get_score(self):
        return self.score

# %%
class ScoreCalc(object):
    def __init__(self, losses, corrects, batch_size):
        self.losses = losses
        self.corrects = corrects
        
        self.batch_size = batch_size
        
        self.len_l = len(losses)
        self.len_c = len(corrects)
        
        self.train_losses = [[] for l in range(self.len_l)]
        self.train_corrects = [[] for c in range(self.len_c)]
        
        self.test_losses = [[] for l in range(self.len_l)]
        self.test_corrects = [[] for c in range(self.len_c)]

        patience = 50

        self.early_stopping = EarlyStopping(patience=patience, verbose=True)
       
    
    def calc_sum(self, losses, corrects):
        if len(losses) != len(self.losses):
            print("warning : len(losses) != len(self.losses)")
            sys.exit()
        if len(corrects) != len(self.corrects):
            print("warning : len(corrects) != len(self.corrects)")
            sys.exit()
        
        for l in range(self.len_l):
            self.losses[l].sum_score(losses[l])
        
        for c in range(self.len_c):
            self.corrects[c].sum_score(corrects[c])
        
        return self.losses, self.corrects
    
    
    def score_del(self):
        for loss in self.losses:
            loss.init_score()
        for correct in self.corrects:
            correct.init_score()

        
    def score_print(self, data_num, train = True):
        if train:
            print("train mean loss={}, accuracy={}".format(self.losses[0].get_score()*self.batch_size/data_num, float(self.corrects[0].get_score()/data_num)))
        else:
            
            print("test mean loss={}, accuracy={}".format(self.losses[0].get_score()*self.batch_size/data_num, float(self.corrects[0].get_score()/data_num)))
            self.early_stopping(self.losses[0].get_score()*self.batch_size/data_num, model_s)
        
            if self.early_stopping.early_stop:
                print("Early stopping")
                return True
            else:
              return False

            
    def score_append(self, data_num, train = True):
        if train:
            for l in range(self.len_l):
                self.train_losses[l].append(self.losses[l].get_score()*self.batch_size/data_num)
            for c in range(self.len_c):
                self.train_corrects[c].append(float(self.corrects[c].get_score()/data_num))
        else:
            for l in range(self.len_l):
                self.test_losses[l].append(self.losses[l].get_score()*self.batch_size/data_num)
            for c in range(self.len_c):
                self.test_corrects[c].append(float(self.corrects[c].get_score()/data_num))
    
    
    def get_value(self, train = True):
        if train:
            return self.train_losses, self.train_corrects
        else:
            return self.test_losses, self.test_corrects

# %%
# to manage all scores
loss = Score()
loss_s = Score()
loss_t = Score()
correct = Score()
score_loss = [loss, loss_s, loss_t]
score_correct = [correct]
sc = ScoreCalc(score_loss, score_correct, BATCH_SIZE)

# %%
# training and test
for epoch in range(EPOCH):
    print('epoch', epoch+1)
    
    c = 0
    for (inputs, labels) in tri_trainloader:
        c+=1
        print("\rIteration: {}/{}".format(c, len(tri_trainloader)), end="")
        img1_t = inputs[0].to(device)
        img2_s = inputs[0].to(device)
        img3_s = inputs[1].to(device)
        
        images = (img1_t, img2_s, img3_s)
        
        label1_t = labels[0].to(device)
        label2_s = labels[0].to(device)
        label3_s = labels[1].to(device)
        
        label = (label1_t, label2_s, label3_s)
        
        fit.train(images, label, KD_LAMBDA)
    c = 0
    print("Train Loss Calc")
    for (inputs, labels) in tri_trainloader:
        c+=1
        print("\rIteration: {}/{}".format(c, len(tri_trainloader)), end="")
        img1_t = inputs[0].to(device)
        img2_s = inputs[0].to(device)
        img3_s = inputs[1].to(device)
        
        images = (img1_t, img2_s, img3_s)
        
        label1_t = labels[0].to(device)
        label2_s = labels[0].to(device)
        label3_s = labels[1].to(device)
        
        label = (label1_t, label2_s, label3_s)
        
        losses, corrects = fit.test(images, label, KD_LAMBDA)
        
        sc.calc_sum(losses, corrects)
    
    sc.score_print(len(trainset))
    sc.score_append(len(trainset))
    sc.score_del()
    c = 0
    print("Test Loss Calc")
    for (inputs, labels) in tri_testloader:
        c+=1
        
        print("\rIteration: {}/{}".format(c, len(tri_testloader)), end="")
        img1_t = inputs[0].to(device)
        img2_s = inputs[0].to(device)
        img3_s = inputs[1].to(device)
        
        images = (img1_t, img2_s, img3_s)
        
        label1_t = labels[0].to(device)
        label2_s = labels[0].to(device)
        label3_s = labels[1].to(device)
        
        label = (label1_t, label2_s, label3_s)
        
        losses, corrects = fit.test(images, label, KD_LAMBDA)
        
        sc.calc_sum(losses, corrects)
    
    if sc.score_print(len(testset), train = False):
      sc.score_append(len(testset), train = False)
      sc.score_del()
      break

    sc.score_append(len(testset), train = False)
    sc.score_del()
    
    scheduler.step()
# Out:
# epoch 1
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=9.275470718383788, accuracy=0.35328
# Test Loss Calc
# Iteration: 100/100test mean loss=8.92939483165741, accuracy=0.3592
# Validation loss decreased (inf --> 8.929395).  Saving model ...
# epoch 2
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=6.687873103141785, accuracy=0.52832
# Test Loss Calc
# Iteration: 100/100test mean loss=6.519526944160462, accuracy=0.5268
# Validation loss decreased (8.929395 --> 6.519527).  Saving model ...
# epoch 3
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=6.32135907459259, accuracy=0.56432
# Test Loss Calc
# Iteration: 100/100test mean loss=6.214866018295288, accuracy=0.5555
# Validation loss decreased (6.519527 --> 6.214866).  Saving model ...
# epoch 4
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=5.295102890968323, accuracy=0.62004
# Test Loss Calc
# Iteration: 100/100test mean loss=5.336611981391907, accuracy=0.6006
# Validation loss decreased (6.214866 --> 5.336612).  Saving model ...
# epoch 5
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=5.320989361286164, accuracy=0.61196
# Test Loss Calc
# Iteration: 100/100test mean loss=5.421164860725403, accuracy=0.5952
# EarlyStopping counter: 1 out of 50
# epoch 6
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=4.9089338278770445, accuracy=0.65772
# Test Loss Calc
# Iteration: 100/100test mean loss=5.164767003059387, accuracy=0.6335
# Validation loss decreased (5.336612 --> 5.164767).  Saving model ...
# epoch 7
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=4.270918912410736, accuracy=0.69482
# Test Loss Calc
# Iteration: 100/100test mean loss=4.500544812679291, accuracy=0.6679
# Validation loss decreased (5.164767 --> 4.500545).  Saving model ...
# epoch 8
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=4.080522715568542, accuracy=0.70946
# Test Loss Calc
# Iteration: 100/100test mean loss=4.377488305568695, accuracy=0.6709
# Validation loss decreased (4.500545 --> 4.377488).  Saving model ...
# epoch 9
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=4.052653670787811, accuracy=0.71372
# Test Loss Calc
# Iteration: 100/100test mean loss=4.424403057098389, accuracy=0.675
# EarlyStopping counter: 1 out of 50
# epoch 10
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.8937552614212034, accuracy=0.72282
# Test Loss Calc
# Iteration: 100/100test mean loss=4.311784372329712, accuracy=0.6822
# Validation loss decreased (4.377488 --> 4.311784).  Saving model ...
# epoch 11
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.8872131171226503, accuracy=0.72918
# Test Loss Calc
# Iteration: 100/100test mean loss=4.2180761408805845, accuracy=0.6919
# Validation loss decreased (4.311784 --> 4.218076).  Saving model ...
# epoch 12
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=4.17328296661377, accuracy=0.71982
# Test Loss Calc
# Iteration: 100/100test mean loss=4.546864821910858, accuracy=0.6792
# EarlyStopping counter: 1 out of 50
# epoch 13
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.6791969952583314, accuracy=0.73964
# Test Loss Calc
# Iteration: 100/100test mean loss=4.120286250114441, accuracy=0.7034
# Validation loss decreased (4.218076 --> 4.120286).  Saving model ...
# epoch 14
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.615851484298706, accuracy=0.74986
# Test Loss Calc
# Iteration: 100/100test mean loss=4.063254208564758, accuracy=0.7048
# Validation loss decreased (4.120286 --> 4.063254).  Saving model ...
# epoch 15
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=4.370495668888092, accuracy=0.69612
# Test Loss Calc
# Iteration: 100/100test mean loss=4.9210654067993165, accuracy=0.6492
# EarlyStopping counter: 1 out of 50
# epoch 16
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.8367304897308347, accuracy=0.74282
# Test Loss Calc
# Iteration: 100/100test mean loss=4.371440434455872, accuracy=0.7019
# EarlyStopping counter: 2 out of 50
# epoch 17
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.429530177116394, accuracy=0.76176
# Test Loss Calc
# Iteration: 100/100test mean loss=3.9688500118255616, accuracy=0.7178
# Validation loss decreased (4.063254 --> 3.968850).  Saving model ...
# epoch 18
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.263982391357422, accuracy=0.77516
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7564088439941408, accuracy=0.7295
# Validation loss decreased (3.968850 --> 3.756409).  Saving model ...
# epoch 19
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.501518175125122, accuracy=0.76306
# Test Loss Calc
# Iteration: 100/100test mean loss=4.003198382854461, accuracy=0.7154
# EarlyStopping counter: 1 out of 50
# epoch 20
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=4.2519662222862245, accuracy=0.7087
# Test Loss Calc
# Iteration: 100/100test mean loss=4.744444291591645, accuracy=0.6602
# EarlyStopping counter: 2 out of 50
# epoch 21
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.4335146527290346, accuracy=0.766
# Test Loss Calc
# Iteration: 100/100test mean loss=3.9691837000846864, accuracy=0.7159
# EarlyStopping counter: 3 out of 50
# epoch 22
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.1857682561874388, accuracy=0.77958
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7966954040527345, accuracy=0.728
# EarlyStopping counter: 4 out of 50
# epoch 23
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.338737012386322, accuracy=0.77272
# Test Loss Calc
# Iteration: 100/100test mean loss=3.881795701980591, accuracy=0.7239
# EarlyStopping counter: 5 out of 50
# epoch 24
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.5265340299606325, accuracy=0.75892
# Test Loss Calc
# Iteration: 100/100test mean loss=4.048409550189972, accuracy=0.7077
# EarlyStopping counter: 6 out of 50
# epoch 25
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.6203179731369017, accuracy=0.7528
# Test Loss Calc
# Iteration: 100/100test mean loss=4.155091869831085, accuracy=0.7045
# EarlyStopping counter: 7 out of 50
# epoch 26
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.51155660533905, accuracy=0.76058
# Test Loss Calc
# Iteration: 100/100test mean loss=4.075860352516174, accuracy=0.7071
# EarlyStopping counter: 8 out of 50
# epoch 27
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.3631786642074584, accuracy=0.76212
# Test Loss Calc
# Iteration: 100/100test mean loss=3.9816233634948732, accuracy=0.7155
# EarlyStopping counter: 9 out of 50
# epoch 28
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.662535695552826, accuracy=0.74862
# Test Loss Calc
# Iteration: 100/100test mean loss=4.23378279209137, accuracy=0.698
# EarlyStopping counter: 10 out of 50
# epoch 29
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.3378039112091065, accuracy=0.76466
# Test Loss Calc
# Iteration: 100/100test mean loss=3.929541141986847, accuracy=0.7106
# EarlyStopping counter: 11 out of 50
# epoch 30
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.373770933151245, accuracy=0.77548
# Test Loss Calc
# Iteration: 100/100test mean loss=3.9646353912353516, accuracy=0.727
# EarlyStopping counter: 12 out of 50
# epoch 31
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.314478216648102, accuracy=0.7671
# Test Loss Calc
# Iteration: 100/100test mean loss=3.9727741432189942, accuracy=0.7105
# EarlyStopping counter: 13 out of 50
# epoch 32
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.2367825689315795, accuracy=0.7805
# Test Loss Calc
# Iteration: 100/100test mean loss=3.82145717382431, accuracy=0.7259
# EarlyStopping counter: 14 out of 50
# epoch 33
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.3543548669815064, accuracy=0.7765
# Test Loss Calc
# Iteration: 100/100test mean loss=4.020792279243469, accuracy=0.7172
# EarlyStopping counter: 15 out of 50
# epoch 34
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.1826846599578857, accuracy=0.78264
# Test Loss Calc
# Iteration: 100/100test mean loss=3.8355817770957947, accuracy=0.725
# EarlyStopping counter: 16 out of 50
# epoch 35
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.5759709696769715, accuracy=0.75104
# Test Loss Calc
# Iteration: 100/100test mean loss=4.1311409330368045, accuracy=0.7037
# EarlyStopping counter: 17 out of 50
# epoch 36
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.089906581878662, accuracy=0.79328
# Test Loss Calc
# Iteration: 100/100test mean loss=3.713754358291626, accuracy=0.7374
# Validation loss decreased (3.756409 --> 3.713754).  Saving model ...
# epoch 37
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0816122431755066, accuracy=0.78594
# Test Loss Calc
# Iteration: 100/100test mean loss=3.713182122707367, accuracy=0.7301
# Validation loss decreased (3.713754 --> 3.713182).  Saving model ...
# epoch 38
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0511335456371307, accuracy=0.7909
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7019774985313414, accuracy=0.7348
# Validation loss decreased (3.713182 --> 3.701977).  Saving model ...
# epoch 39
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.222332461833954, accuracy=0.77976
# Test Loss Calc
# Iteration: 100/100test mean loss=3.8211659264564513, accuracy=0.723
# EarlyStopping counter: 1 out of 50
# epoch 40
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.1852358570098875, accuracy=0.78574
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7888777828216553, accuracy=0.7343
# EarlyStopping counter: 2 out of 50
# epoch 41
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0547224655151366, accuracy=0.79554
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7059237480163576, accuracy=0.7391
# EarlyStopping counter: 3 out of 50
# epoch 42
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.931154243707657, accuracy=0.79468
# Test Loss Calc
# Iteration: 100/100test mean loss=3.5887801885604858, accuracy=0.7353
# Validation loss decreased (3.701977 --> 3.588780).  Saving model ...
# epoch 43
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0218622913360598, accuracy=0.7964
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7064426493644715, accuracy=0.7427
# EarlyStopping counter: 1 out of 50
# epoch 44
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9730728278160097, accuracy=0.80032
# Test Loss Calc
# Iteration: 100/100test mean loss=3.5896401834487914, accuracy=0.7398
# EarlyStopping counter: 2 out of 50
# epoch 45
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.1487169542312623, accuracy=0.78254
# Test Loss Calc
# Iteration: 100/100test mean loss=3.822194905281067, accuracy=0.7299
# EarlyStopping counter: 3 out of 50
# epoch 46
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.3287023477554323, accuracy=0.77488
# Test Loss Calc
# Iteration: 100/100test mean loss=3.9510831880569457, accuracy=0.7143
# EarlyStopping counter: 4 out of 50
# epoch 47
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.278804958343506, accuracy=0.77758
# Test Loss Calc
# Iteration: 100/100test mean loss=3.919571731090546, accuracy=0.723
# EarlyStopping counter: 5 out of 50
# epoch 48
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9561958446502685, accuracy=0.79978
# Test Loss Calc
# Iteration: 100/100test mean loss=3.648676805496216, accuracy=0.7449
# EarlyStopping counter: 6 out of 50
# epoch 49
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.1664174466133117, accuracy=0.7905
# Test Loss Calc
# Iteration: 100/100test mean loss=3.8432886171340943, accuracy=0.7362
# EarlyStopping counter: 7 out of 50
# epoch 50
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.2505563097000123, accuracy=0.78936
# Test Loss Calc
# Iteration: 100/100test mean loss=3.8743356466293335, accuracy=0.7291
# EarlyStopping counter: 8 out of 50
# epoch 51
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9791242065429686, accuracy=0.8012
# Test Loss Calc
# Iteration: 100/100test mean loss=3.6344741106033327, accuracy=0.7456
# EarlyStopping counter: 9 out of 50
# epoch 52
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.4850743370056154, accuracy=0.74936
# Test Loss Calc
# Iteration: 100/100test mean loss=4.069032778739929, accuracy=0.6969
# EarlyStopping counter: 10 out of 50
# epoch 53
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.078822147846222, accuracy=0.7901
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7201152563095095, accuracy=0.7331
# EarlyStopping counter: 11 out of 50
# epoch 54
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.3569614410400392, accuracy=0.77848
# Test Loss Calc
# Iteration: 100/100test mean loss=3.9600925636291504, accuracy=0.7283
# EarlyStopping counter: 12 out of 50
# epoch 55
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.260607364654541, accuracy=0.78408
# Test Loss Calc
# Iteration: 100/100test mean loss=3.892183880805969, accuracy=0.7266
# EarlyStopping counter: 13 out of 50
# epoch 56
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0017906823158262, accuracy=0.79682
# Test Loss Calc
# Iteration: 100/100test mean loss=3.690240132808685, accuracy=0.7394
# EarlyStopping counter: 14 out of 50
# epoch 57
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.06957390832901, accuracy=0.79144
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7141886854171755, accuracy=0.7335
# EarlyStopping counter: 15 out of 50
# epoch 58
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9000746202468872, accuracy=0.80298
# Test Loss Calc
# Iteration: 100/100test mean loss=3.59174592256546, accuracy=0.7432
# EarlyStopping counter: 16 out of 50
# epoch 59
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0907857661247253, accuracy=0.7971
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7993480229377745, accuracy=0.74
# EarlyStopping counter: 17 out of 50
# epoch 60
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.3303791604042052, accuracy=0.77644
# Test Loss Calc
# Iteration: 100/100test mean loss=3.968195979595184, accuracy=0.7212
# EarlyStopping counter: 18 out of 50
# epoch 61
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9631896743774413, accuracy=0.80024
# Test Loss Calc
# Iteration: 100/100test mean loss=3.59255429983139, accuracy=0.7439
# EarlyStopping counter: 19 out of 50
# epoch 62
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.532750692844391, accuracy=0.75972
# Test Loss Calc
# Iteration: 100/100test mean loss=4.219371671676636, accuracy=0.6949
# EarlyStopping counter: 20 out of 50
# epoch 63
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.256410519123077, accuracy=0.78628
# Test Loss Calc
# Iteration: 100/100test mean loss=3.8988285303115844, accuracy=0.7292
# EarlyStopping counter: 21 out of 50
# epoch 64
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9374464411735532, accuracy=0.79966
# Test Loss Calc
# Iteration: 100/100test mean loss=3.5972433853149415, accuracy=0.7415
# EarlyStopping counter: 22 out of 50
# epoch 65
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0502982840538024, accuracy=0.78732
# Test Loss Calc
# Iteration: 100/100test mean loss=3.720977296829224, accuracy=0.7268
# EarlyStopping counter: 23 out of 50
# epoch 66
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.2019007658958434, accuracy=0.78338
# Test Loss Calc
# Iteration: 100/100test mean loss=3.8215212416648865, accuracy=0.724
# EarlyStopping counter: 24 out of 50
# epoch 67
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.7724252688884734, accuracy=0.80942
# Test Loss Calc
# Iteration: 100/100test mean loss=3.5026170229911804, accuracy=0.7479
# Validation loss decreased (3.588780 --> 3.502617).  Saving model ...
# epoch 68
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.3370587439537047, accuracy=0.77346
# Test Loss Calc
# Iteration: 100/100test mean loss=3.941631295681, accuracy=0.723
# EarlyStopping counter: 1 out of 50
# epoch 69
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0542266573905943, accuracy=0.79788
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7431369757652284, accuracy=0.737
# EarlyStopping counter: 2 out of 50
# epoch 70
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.898065943479538, accuracy=0.80744
# Test Loss Calc
# Iteration: 100/100test mean loss=3.5524021649360655, accuracy=0.7522
# EarlyStopping counter: 3 out of 50
# epoch 71
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0206292116642, accuracy=0.79446
# Test Loss Calc
# Iteration: 100/100test mean loss=3.6434689593315124, accuracy=0.7366
# EarlyStopping counter: 4 out of 50
# epoch 72
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8525621099472045, accuracy=0.8081
# Test Loss Calc
# Iteration: 100/100test mean loss=3.544735791683197, accuracy=0.7463
# EarlyStopping counter: 5 out of 50
# epoch 73
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.1242081661224366, accuracy=0.7857
# Test Loss Calc
# Iteration: 100/100test mean loss=3.824944818019867, accuracy=0.7253
# EarlyStopping counter: 6 out of 50
# epoch 74
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.892556938648224, accuracy=0.80768
# Test Loss Calc
# Iteration: 100/100test mean loss=3.51202143907547, accuracy=0.7494
# EarlyStopping counter: 7 out of 50
# epoch 75
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.062146396636963, accuracy=0.79772
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7502871918678284, accuracy=0.7441
# EarlyStopping counter: 8 out of 50
# epoch 76
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.90202635884285, accuracy=0.80372
# Test Loss Calc
# Iteration: 100/100test mean loss=3.5857214856147768, accuracy=0.7431
# EarlyStopping counter: 9 out of 50
# epoch 77
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.008997705936432, accuracy=0.80062
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7434928679466246, accuracy=0.7411
# EarlyStopping counter: 10 out of 50
# epoch 78
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.733230924844742, accuracy=0.81718
# Test Loss Calc
# Iteration: 100/100test mean loss=3.4439320611953734, accuracy=0.7543
# Validation loss decreased (3.502617 --> 3.443932).  Saving model ...
# epoch 79
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.075126940727234, accuracy=0.79754
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7585323071479797, accuracy=0.737
# EarlyStopping counter: 1 out of 50
# epoch 80
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0591684098243714, accuracy=0.79128
# Test Loss Calc
# Iteration: 100/100test mean loss=3.6702584791183472, accuracy=0.7321
# EarlyStopping counter: 2 out of 50
# epoch 81
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.981493556022644, accuracy=0.80342
# Test Loss Calc
# Iteration: 100/100test mean loss=3.6506873631477355, accuracy=0.74
# EarlyStopping counter: 3 out of 50
# epoch 82
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.0569432487487793, accuracy=0.795
# Test Loss Calc
# Iteration: 100/100test mean loss=3.6659351706504824, accuracy=0.7352
# EarlyStopping counter: 4 out of 50
# epoch 83
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8934278450012205, accuracy=0.8159
# Test Loss Calc
# Iteration: 100/100test mean loss=3.6105956053733825, accuracy=0.7585
# EarlyStopping counter: 5 out of 50
# epoch 84
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.17324960231781, accuracy=0.79088
# Test Loss Calc
# Iteration: 100/100test mean loss=3.8505670547485353, accuracy=0.7334
# EarlyStopping counter: 6 out of 50
# epoch 85
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.463528800487518, accuracy=0.76816
# Test Loss Calc
# Iteration: 100/100test mean loss=4.049561471939087, accuracy=0.7143
# EarlyStopping counter: 7 out of 50
# epoch 86
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.2703735535144807, accuracy=0.77936
# Test Loss Calc
# Iteration: 100/100test mean loss=3.9685187673568727, accuracy=0.7206
# EarlyStopping counter: 8 out of 50
# epoch 87
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.946878009557724, accuracy=0.8042
# Test Loss Calc
# Iteration: 100/100test mean loss=3.66769428730011, accuracy=0.7453
# EarlyStopping counter: 9 out of 50
# epoch 88
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.9759214577674866, accuracy=0.8017
# Test Loss Calc
# Iteration: 100/100test mean loss=3.653424665927887, accuracy=0.7447
# EarlyStopping counter: 10 out of 50
# epoch 89
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8525136868953704, accuracy=0.81324
# Test Loss Calc
# Iteration: 100/100test mean loss=3.4787038469314577, accuracy=0.7572
# EarlyStopping counter: 11 out of 50
# epoch 90
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8035364491939543, accuracy=0.82074
# Test Loss Calc
# Iteration: 100/100test mean loss=3.51866557598114, accuracy=0.7522
# EarlyStopping counter: 12 out of 50
# epoch 91
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.882608452320099, accuracy=0.81118
# Test Loss Calc
# Iteration: 100/100test mean loss=3.616809301376343, accuracy=0.7487
# EarlyStopping counter: 13 out of 50
# epoch 92
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.1284230012893675, accuracy=0.8002
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7909060430526735, accuracy=0.7375
# EarlyStopping counter: 14 out of 50
# epoch 93
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.726361886024475, accuracy=0.81882
# Test Loss Calc
# Iteration: 100/100test mean loss=3.46462646484375, accuracy=0.7568
# EarlyStopping counter: 15 out of 50
# epoch 94
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.8617731614112856, accuracy=0.81148
# Test Loss Calc
# Iteration: 100/100test mean loss=3.5282895374298096, accuracy=0.7519
# EarlyStopping counter: 16 out of 50
# epoch 95
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.099999626159668, accuracy=0.79436
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7333128523826598, accuracy=0.7323
# EarlyStopping counter: 17 out of 50
# epoch 96
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=3.584032524585724, accuracy=0.76456
# Test Loss Calc
# Iteration: 100/100test mean loss=4.13985178232193, accuracy=0.7122
# EarlyStopping counter: 18 out of 50
# epoch 97
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.954950049638748, accuracy=0.80322
# Test Loss Calc
# Iteration: 100/100test mean loss=3.6498976373672485, accuracy=0.7407
# EarlyStopping counter: 19 out of 50
# epoch 98
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.7997828481197358, accuracy=0.81078
# Test Loss Calc
# Iteration: 100/100test mean loss=3.518998095989227, accuracy=0.7498
# EarlyStopping counter: 20 out of 50
# epoch 99
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.969173910140991, accuracy=0.8036
# Test Loss Calc
# Iteration: 100/100test mean loss=3.7021267461776732, accuracy=0.7446
# EarlyStopping counter: 21 out of 50
# epoch 100
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=2.770832903623581, accuracy=0.81362
# Test Loss Calc
# Iteration: 100/100test mean loss=3.5500391364097594, accuracy=0.7407
# EarlyStopping counter: 22 out of 50
# epoch 101
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.9228604383468628, accuracy=0.87288
# Test Loss Calc
# Iteration: 100/100test mean loss=2.819042224884033, accuracy=0.7941
# Validation loss decreased (3.443932 --> 2.819042).  Saving model ...
# epoch 102
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.8610372288227082, accuracy=0.87932
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7828188014030455, accuracy=0.7989
# Validation loss decreased (2.819042 --> 2.782819).  Saving model ...
# epoch 103
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.7480526609420777, accuracy=0.88832
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7309068417549134, accuracy=0.8026
# Validation loss decreased (2.782819 --> 2.730907).  Saving model ...
# epoch 104
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.7013666526079179, accuracy=0.8936
# Test Loss Calc
# Iteration: 100/100test mean loss=2.684354535341263, accuracy=0.8052
# Validation loss decreased (2.730907 --> 2.684355).  Saving model ...
# epoch 105
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.6848434422016143, accuracy=0.89432
# Test Loss Calc
# Iteration: 100/100test mean loss=2.696181960105896, accuracy=0.8039
# EarlyStopping counter: 1 out of 50
# epoch 106
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.629248846411705, accuracy=0.90096
# Test Loss Calc
# Iteration: 100/100test mean loss=2.669383282661438, accuracy=0.809
# Validation loss decreased (2.684355 --> 2.669383).  Saving model ...
# epoch 107
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.6147710888385773, accuracy=0.90232
# Test Loss Calc
# Iteration: 100/100test mean loss=2.692145149707794, accuracy=0.8071
# EarlyStopping counter: 1 out of 50
# epoch 108
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.6173153574466705, accuracy=0.90336
# Test Loss Calc
# Iteration: 100/100test mean loss=2.68328250169754, accuracy=0.809
# EarlyStopping counter: 2 out of 50
# epoch 109
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5864527274370193, accuracy=0.90354
# Test Loss Calc
# Iteration: 100/100test mean loss=2.692721184492111, accuracy=0.8077
# EarlyStopping counter: 3 out of 50
# epoch 110
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5536996111869812, accuracy=0.90736
# Test Loss Calc
# Iteration: 100/100test mean loss=2.6838209939002993, accuracy=0.8072
# EarlyStopping counter: 4 out of 50
# epoch 111
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5673134758472442, accuracy=0.91028
# Test Loss Calc
# Iteration: 100/100test mean loss=2.6977355897426607, accuracy=0.81
# EarlyStopping counter: 5 out of 50
# epoch 112
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5868079431056976, accuracy=0.9072
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7234433364868162, accuracy=0.8039
# EarlyStopping counter: 6 out of 50
# epoch 113
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5045840430259705, accuracy=0.91294
# Test Loss Calc
# Iteration: 100/100test mean loss=2.6819847774505616, accuracy=0.8117
# EarlyStopping counter: 7 out of 50
# epoch 114
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5205789067745208, accuracy=0.91214
# Test Loss Calc
# Iteration: 100/100test mean loss=2.6987427723407746, accuracy=0.8042
# EarlyStopping counter: 8 out of 50
# epoch 115
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4743159347772599, accuracy=0.91458
# Test Loss Calc
# Iteration: 100/100test mean loss=2.6726790511608125, accuracy=0.81
# EarlyStopping counter: 9 out of 50
# epoch 116
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4770888726711273, accuracy=0.91684
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7010134840011597, accuracy=0.8085
# EarlyStopping counter: 10 out of 50
# epoch 117
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.539290206193924, accuracy=0.91584
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7719759511947633, accuracy=0.8055
# EarlyStopping counter: 11 out of 50
# epoch 118
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5306884775161742, accuracy=0.91848
# Test Loss Calc
# Iteration: 100/100test mean loss=2.768016058206558, accuracy=0.8079
# EarlyStopping counter: 12 out of 50
# epoch 119
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4309704008102417, accuracy=0.92386
# Test Loss Calc
# Iteration: 100/100test mean loss=2.6982557129859925, accuracy=0.8111
# EarlyStopping counter: 13 out of 50
# epoch 120
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.5011345862150192, accuracy=0.91578
# Test Loss Calc
# Iteration: 100/100test mean loss=2.768301924467087, accuracy=0.8037
# EarlyStopping counter: 14 out of 50
# epoch 121
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4087687327861786, accuracy=0.92474
# Test Loss Calc
# Iteration: 100/100test mean loss=2.6972069346904757, accuracy=0.813
# EarlyStopping counter: 15 out of 50
# epoch 122
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4635776962041855, accuracy=0.9203
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7265132117271422, accuracy=0.8021
# EarlyStopping counter: 16 out of 50
# epoch 123
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.463894803404808, accuracy=0.92112
# Test Loss Calc
# Iteration: 100/100test mean loss=2.790147967338562, accuracy=0.8078
# EarlyStopping counter: 17 out of 50
# epoch 124
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4097274943590163, accuracy=0.92884
# Test Loss Calc
# Iteration: 100/100test mean loss=2.736476846933365, accuracy=0.8081
# EarlyStopping counter: 18 out of 50
# epoch 125
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3539682132005693, accuracy=0.93128
# Test Loss Calc
# Iteration: 100/100test mean loss=2.6925424945354464, accuracy=0.8121
# EarlyStopping counter: 19 out of 50
# epoch 126
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.377532483816147, accuracy=0.93028
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7322127175331117, accuracy=0.8106
# EarlyStopping counter: 20 out of 50
# epoch 127
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.416712003827095, accuracy=0.92872
# Test Loss Calc
# Iteration: 100/100test mean loss=2.779644961357117, accuracy=0.8062
# EarlyStopping counter: 21 out of 50
# epoch 128
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3834207804203034, accuracy=0.92998
# Test Loss Calc
# Iteration: 100/100test mean loss=2.73012619137764, accuracy=0.8084
# EarlyStopping counter: 22 out of 50
# epoch 129
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.4227694449424744, accuracy=0.9264
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7773482823371887, accuracy=0.8042
# EarlyStopping counter: 23 out of 50
# epoch 130
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.33530286693573, accuracy=0.9327
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7102928948402405, accuracy=0.8117
# EarlyStopping counter: 24 out of 50
# epoch 131
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3468026673793794, accuracy=0.93556
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7300259590148928, accuracy=0.8128
# EarlyStopping counter: 25 out of 50
# epoch 132
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3602288656234742, accuracy=0.934
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7368900191783907, accuracy=0.8099
# EarlyStopping counter: 26 out of 50
# epoch 133
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3784936012029647, accuracy=0.93204
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7500475335121153, accuracy=0.808
# EarlyStopping counter: 27 out of 50
# epoch 134
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3955531660318374, accuracy=0.93052
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7767698550224305, accuracy=0.8057
# EarlyStopping counter: 28 out of 50
# epoch 135
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.311680390238762, accuracy=0.93556
# Test Loss Calc
# Iteration: 100/100test mean loss=2.745249596834183, accuracy=0.8077
# EarlyStopping counter: 29 out of 50
# epoch 136
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.2996939866542816, accuracy=0.93666
# Test Loss Calc
# Iteration: 100/100test mean loss=2.742753349542618, accuracy=0.8082
# EarlyStopping counter: 30 out of 50
# epoch 137
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.326384236097336, accuracy=0.9339
# Test Loss Calc
# Iteration: 100/100test mean loss=2.759980893135071, accuracy=0.8021
# EarlyStopping counter: 31 out of 50
# epoch 138
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3520912121534348, accuracy=0.93156
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7982803058624266, accuracy=0.8017
# EarlyStopping counter: 32 out of 50
# epoch 139
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.2950792537927627, accuracy=0.9377
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7538570308685304, accuracy=0.809
# EarlyStopping counter: 33 out of 50
# epoch 140
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3465962654352188, accuracy=0.93502
# Test Loss Calc
# Iteration: 100/100test mean loss=2.8062196588516235, accuracy=0.8048
# EarlyStopping counter: 34 out of 50
# epoch 141
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.277378521323204, accuracy=0.94102
# Test Loss Calc
# Iteration: 100/100test mean loss=2.736432223320007, accuracy=0.8082
# EarlyStopping counter: 35 out of 50
# epoch 142
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3062219110727311, accuracy=0.94026
# Test Loss Calc
# Iteration: 100/100test mean loss=2.795390441417694, accuracy=0.8081
# EarlyStopping counter: 36 out of 50
# epoch 143
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3204038760662078, accuracy=0.93606
# Test Loss Calc
# Iteration: 100/100test mean loss=2.8000577664375306, accuracy=0.8023
# EarlyStopping counter: 37 out of 50
# epoch 144
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.30158249270916, accuracy=0.93652
# Test Loss Calc
# Iteration: 100/100test mean loss=2.794712690114975, accuracy=0.8066
# EarlyStopping counter: 38 out of 50
# epoch 145
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.2678276557922363, accuracy=0.9429
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7785665547847747, accuracy=0.8088
# EarlyStopping counter: 39 out of 50
# epoch 146
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.2906716579198838, accuracy=0.93858
# Test Loss Calc
# Iteration: 100/100test mean loss=2.7906700444221495, accuracy=0.8074
# EarlyStopping counter: 40 out of 50
# epoch 147
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3114746375083923, accuracy=0.93742
# Test Loss Calc
# Iteration: 100/100test mean loss=2.8162367153167724, accuracy=0.8042
# EarlyStopping counter: 41 out of 50
# epoch 148
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3379349868297576, accuracy=0.93822
# Test Loss Calc
# Iteration: 100/100test mean loss=2.8402128553390504, accuracy=0.8057
# EarlyStopping counter: 42 out of 50
# epoch 149
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.3733488790988921, accuracy=0.93778
# Test Loss Calc
# Iteration: 100/100test mean loss=2.880299050807953, accuracy=0.8061
# EarlyStopping counter: 43 out of 50
# epoch 150
# Iteration: 500/500Train Loss Calc
# Iteration: 500/500train mean loss=1.2827907221317292, accuracy=0.9432
# Test Loss Calc
# Iteration: 100/100test mean loss=2.821686806678772, accuracy=0.8068
# EarlyStopping counter: 44 out of 50

# %%
# get the scores
train_losses, train_corrects = sc.get_value()
test_losses, test_corrects = sc.get_value(train = False)

# %%
def plot_score(epoch, train_data, test_data, x_lim = None, y_lim = None, x_label = 'EPOCH', y_label = 'score', title = 'score', legend = ['train', 'test'], filename = 'test'):
    plt.figure(figsize=(6,6))
    
    if x_lim is None:
        x_lim = epoch
    if y_lim is None:
        y_lim = 1
        
    plt.plot(range(epoch), train_data)
    plt.plot(range(epoch), test_data, c='#00ff00')
    plt.xlim(0, x_lim)
    plt.ylim(0, y_lim)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.legend(legend)
    plt.title(title)
    plt.savefig(filename+'.png')
    plt.close()

    
def save_data(train_loss, test_loss, train_acc, test_acc, filename):
    with open(filename + '.txt', mode='w') as f:
        f.write("train mean loss={}\n".format(train_loss[-1]))
        f.write("test  mean loss={}\n".format(test_loss[-1]))
        f.write("train accuracy={}\n".format(train_acc[-1]))
        f.write("test  accuracy={}\n".format(test_acc[-1]))

# %%
torch.save(model_s.state_dict(), fnnname + '.pth')

# %%
save_data(train_losses[0], test_losses[0], train_corrects[0], test_corrects[0], result_name)

# %%
# output the glaphs of the scores

plot_score(150, train_losses[0], test_losses[0], y_lim = 5.0, y_label = 'LOSS', legend = ['train loss', 'test loss'], title = 'total loss', filename = total_loss_name)

plot_score(150, train_losses[1], test_losses[1], y_lim = 5.0, y_label = 'LOSS', legend = ['train loss', 'test loss'], title = 'softmax loss', filename = soft_loss_name)

plot_score(150, train_losses[2], test_losses[2], y_lim = 5.0, y_label = 'LOSS', legend = ['train loss', 'test loss'], title = 'triplet loss', filename = tri_loss_name)

plot_score(150, train_corrects[0], test_corrects[0], y_lim = 1, y_label = 'ACCURACY', legend = ['train acc', 'test acc'], title = 'accuracy', filename = acc_name)
